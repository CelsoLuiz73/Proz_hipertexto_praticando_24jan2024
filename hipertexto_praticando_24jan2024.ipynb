# %%
def numerosPares():
  print("Olá, favor digitar qualquer número par:")
  try:
    entrada = float(input())
  except:
    print("Caro usuário, você digitou um caractere inválido, favor digitar um número par.")
    return numerosPares()
  if entrada %2 == 1:
    print("O número digitado é um número impar, favor digitar um núemro par.")
    return numerosPares()
  else:
    print("O número par digitado é : ", entrada)

# %%
numerosPares()
# Out:
# Olá, favor digitar qualquer número par:
# h
# Caro usuário, você digitou um caractere inválido, favor digitar um número par.
# Olá, favor digitar qualquer número par:
# 3
# O número digitado é um número impar, favor digitar um núemro par.
# Olá, favor digitar qualquer número par:
# 2
# O número par digitado é :  2.0
